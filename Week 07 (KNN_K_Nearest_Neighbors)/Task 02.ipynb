# %%
import pandas as pd
import warnings as wr
wr.filterwarnings('ignore')

# %%
df = pd.read_csv('weight-height.csv')
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df.Gender = le.fit_transform(df[['Gender']])

# %%
df.head()
# Out:
#    Gender     Height      Weight
# 0       1  73.847017  241.893563
# 1       1  68.781904  162.310473
# 2       1  74.110105  212.740856
# 3       1  71.730978  220.042470
# 4       1  69.881796  206.349801

# %%
df.tail()
# Out:
#       Gender     Height      Weight
# 8550       0  60.483946  110.565497
# 8551       0  63.423372  129.921671
# 8552       0  65.584057  155.942671
# 8553       0  67.429971  151.678405
# 8554       0  60.921791  131.253738

# %% [markdown]
# <h1>Go Ahead</h1>

# %%
X = df[['Gender','Height']]
X.head()
# Out:
#    Gender     Height
# 0       1  73.847017
# 1       1  68.781904
# 2       1  74.110105
# 3       1  71.730978
# 4       1  69.881796

# %%
y = df.Weight
y.head()
# Out:
# 0    241.893563
# 1    162.310473
# 2    212.740856
# 3    220.042470
# 4    206.349801
# Name: Weight, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X,y,test_size=0.3)

# %%
xtrain
# Out:
#       Gender     Height
# 307        1  68.447579
# 8135       0  71.552205
# 4129       1  67.730275
# 6806       0  66.650540
# 948        1  69.371843
# ...      ...        ...
# 5007       0  65.652156
# 2148       1  70.764598
# 3041       1  65.806015
# 3048       1  70.192414
# 882        1  68.890095
#
# [5988 rows x 2 columns]

# %%
ytrain
# Out:
# 307     187.907426
# 8135    185.658271
# 4129    168.545076
# 6806    158.221301
# 948     173.430170
#            ...
# 5007    165.083001
# 2148    188.792457
# 3041    178.972481
# 3048    198.141175
# 882     194.681435
# Name: Weight, Length: 5988, dtype: float64

# %%
xtrain.shape
# Out:
# (5988, 2)

# %%
xtest.shape
# Out:
# (2567, 2)

# %% [markdown]
# <h1>Least Squared Linear Regression</h1>

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
lr.score(xtest,ytest)
# Out:
# 0.90407326336829

# %%
df['Predict'] = lr.predict(X)
df.head()
# Out:
#    Gender     Height      Weight     Predict
# 0       1  73.847017  241.893563  215.531002
# 1       1  68.781904  162.310473  185.497807
# 2       1  74.110105  212.740856  217.090964
# 3       1  71.730978  220.042470  202.984115
# 4       1  69.881796  206.349801  192.019531

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
mse = mean_squared_error(df['Weight'] , df['Predict'])
mse
# Out:
# 102.73570691038448

# %% [markdown]
# <h1>Regression Problem</h1>

# %%
from sklearn.neighbors import KNeighborsRegressor

knn = KNeighborsRegressor(n_neighbors = 8)

# %%
knn.fit(xtrain,ytrain)
# Out:
# KNeighborsRegressor(n_neighbors=8)

# %%
knn.score(xtest,ytest)
# Out:
# 0.8912005597121062

# %%
mse = mean_squared_error(df['Weight'],knn.predict(X))

# %%
mse
# Out:
# 98.91749477861656

# %% [markdown]
# <h1>Classification</h1>

# %%
df
# Out:
#       Gender     Height      Weight     Predict
# 0          1  73.847017  241.893563  215.531002
# 1          1  68.781904  162.310473  185.497807
# 2          1  74.110105  212.740856  217.090964
# 3          1  71.730978  220.042470  202.984115
# 4          1  69.881796  206.349801  192.019531
# ...      ...        ...         ...         ...
# 8550       0  60.483946  110.565497  116.731559
# 8551       0  63.423372  129.921671  134.160657
# 8552       0  65.584057  155.942671  146.972272
# 8553       0  67.429971  151.678405  157.917480
# 8554       0  60.921791  131.253738  119.327729
#
# [8555 rows x 4 columns]

# %%
X = df[['Height','Weight']]
Y = df.Gender

# %%
X.head()
# Out:
#       Height      Weight
# 0  73.847017  241.893563
# 1  68.781904  162.310473
# 2  74.110105  212.740856
# 3  71.730978  220.042470
# 4  69.881796  206.349801

# %%
Y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 8550    0
# 8551    0
# 8552    0
# 8553    0
# 8554    0
# Name: Gender, Length: 8555, dtype: int32

# %%
x2train,x2test,y2train,y2test = train_test_split(X,Y,test_size=0.3)

# %%
x2train
# Out:
#          Height      Weight
# 4830  70.798271  198.388001
# 2008  66.416414  193.601091
# 6629  60.177351   98.745038
# 3223  69.380499  192.759875
# 5844  66.293920  168.143510
# ...         ...         ...
# 410   68.762458  196.293806
# 2033  73.986690  217.579162
# 668   69.525551  189.707399
# 5972  63.500454  137.198700
# 7465  63.611207  136.645861
#
# [5988 rows x 2 columns]

# %%
x2test
# Out:
#          Height      Weight
# 4238  66.756029  165.989782
# 3195  71.473571  198.077199
# 487   69.937400  202.279070
# 1861  71.113625  202.993311
# 3138  73.432736  208.870918
# ...         ...         ...
# 6967  63.166901  138.029804
# 261   68.091374  181.644445
# 4756  65.078289  163.672481
# 1552  70.837159  201.403402
# 4596  71.368891  205.216922
#
# [2567 rows x 2 columns]

# %%
y2train
# Out:
# 4830    1
# 2008    1
# 6629    0
# 3223    1
# 5844    0
#        ..
# 410     1
# 2033    1
# 668     1
# 5972    0
# 7465    0
# Name: Gender, Length: 5988, dtype: int32

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 8)

# %%
knn.fit(x2train,y2train)
# Out:
# KNeighborsClassifier(n_neighbors=8)

# %%
knn.score(x2test,y2test)
# Out:
# 0.9104012465913518

# %%
df['P_Gender'] = knn.predict(X)

# %%
df
# Out:
#       Gender     Height      Weight     Predict  P_Gender
# 0          1  73.847017  241.893563  215.531002         1
# 1          1  68.781904  162.310473  185.497807         0
# 2          1  74.110105  212.740856  217.090964         1
# 3          1  71.730978  220.042470  202.984115         1
# 4          1  69.881796  206.349801  192.019531         1
# ...      ...        ...         ...         ...       ...
# 8550       0  60.483946  110.565497  116.731559         0
# 8551       0  63.423372  129.921671  134.160657         0
# 8552       0  65.584057  155.942671  146.972272         0
# 8553       0  67.429971  151.678405  157.917480         0
# 8554       0  60.921791  131.253738  119.327729         0
#
# [8555 rows x 5 columns]
